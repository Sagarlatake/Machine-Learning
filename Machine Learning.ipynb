# %% [markdown]
# ### Machine Learning

# %% [raw]
# Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.

# %% [raw]
# Machine learning is an important component of the growing field of data science. Through the use of statistical methods, algorithms are trained to make classifications or predictions, uncovering key insights within data
#
# These insights subsequently drive decision making within applications and businesses
#
# Since deep learning and machine learning tend to be used interchangeably, it’s worth noting the nuances between the two. Machine learning, deep learning, and neural networks are all sub-fields of artificial intelligence. However, deep learning is actually a sub-field of machine learning, and neural networks is a sub-field of deep learning.

# %% [markdown]
# Learning	is	any	process	by	which	a	system	improves
# performance	from	experience.
#
# Machine	Learning	is	the	study	of	algorithms	that
# • improve	their	performance	P
# • at	some	task	T
# • with	experience	E.
# A	well-defined	learning	task	is	given	by	<P,	T,	E>.
#
#
# - Optimize a performance criterion using example data or past experience.
#
# - Role of Statistics: Inference from a sample
#
# - Role of Computer science: Efficient algorithms to Solve the optimization problem
#
# - Representing and evaluating the model for inference

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ![1-%20ml-use.png](attachment:1-%20ml-use.png)

# %% [markdown]
# ![2-ml-application.png](attachment:2-ml-application.png)

# %% [markdown]
# ### Sample	Applications
#
# Web	search
#
# Computational	biology
#
# Finance
#
# E-commerce
#
# Space	exploration
#
# Robotics
#
# Information	extraction
#
# Social	networks
#
# Debugging	software

# %% [markdown]
# # Types	of	Learning
#
# • Supervised	(inductive)	learning
#
# – Given:	training	data	+	desired	outputs	(labels)
#
# • Unsupervised	learning
#
# – Given:	training	data	(without	desired	outputs)
#
# • Semi-supervised	learning
#
# – Given:	training	data	+	a	few	desired	outputs
#
# • Reinforcement	learning
#
# – Rewards	from	sequence	of	actions

# %%
no_rooms, area ===> Price

1   300   10000
2   500   20000
2.5 600   25000
3   800   40000

{no_rooms, area}===> independent features
{Price} ====> Dependent Feature (Labels)
.
.
.
test

5   1000   ????? ====>60000 

Y is categorical---- yes or No, Male or Female

Regression: Values Prediction (Obtain)

Classification: do classification

# %% [markdown]
# ![3-ml-supervised.png](attachment:3-ml-supervised.png)

# %% [markdown]
# ![4-ml-classification.png](attachment:4-ml-classification.png)

# %% [markdown]
# ![5-ml-classification.png](attachment:5-ml-classification.png)

# %% [markdown]
# ![6-ml-unsupervised.png](attachment:6-ml-unsupervised.png)
